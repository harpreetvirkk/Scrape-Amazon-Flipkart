# %% [markdown]
# # Script for extracting product list for a seller
#
# The script takes as input a .txt file containing a list of brands offered by a seller, and then iterates through all the brands in the list.
#
# For each brand in the brand list, it finds all the products offered by the given seller. The details are stored in a .jsonl file.

# %%
import urllib.request # FOR URL ENCODING 
import requests # For making requests to download a webpage content
from selectorlib import Extractor # For extracting specific fileds from downloaded webpage
import json 
import random 
from time import sleep
import os
import jsonlines
import pandas as pd
import datetime
import re

# %% [markdown]
# #### Step 1: Read Brand List
#
# **NOTE:** Before running this, change the path variable 'brands' to point to the Brand List file. The brand list should be in .txt format with each line containing a brand name.
#
# The following code loads a brand list file, and reads all its brands into a list.

# %%
# !ls ../DATASET/BrandLists/
# Out:
# Appario_Brand_List.txt       URL_Encode_List.py
# Cloudtail_Brand_List_A.txt   keywords.txt
# Cloudtail_Brand_List_B.txt   text.txt
# Cloudtail_Brand_List_Top.txt

# %%
brands = open('./../DATASET/BrandLists/Appario_Brand_List.txt', 'r')
# brands = open('./../DATASETS/BrandLists/CloudtailBrandListTop.txt', 'r')

brand_list = []

for b in brands:
     # Removing (\n) from the end of each brand name read
    b = b.strip(" \n")
    b = b.strip("\n")
    brand_list.append(b) 
print('Brand List: ', brand_list[:10])
print('Brand Count: ', len(brand_list))
# Out:
# Brand List:  ['10.or', '100FIT', '1KLICK', '2010KHARIDO', '3M', '4+D+%28LABEL%29', '4D', '5E', 'A-DATA', 'A.W.Faber-Castell']
# Brand Count:  973

# %% [markdown]
# #### Step 2: Define Headers
#
# Each header is a unique user agent which will be used to request the data from the website to be scraped. We use multiple user agents to ensure that if our request is rejected, we can retry.
#
# To create more headers, simply copy any one of the old headers and replace the 'user-agent' string with a new 'user-agent' string, which can be found online. (Eg. https://developer.chrome.com/multidevice/user-agent)

# %%
headers = [
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.111 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1 Safari/605.1.15',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.70 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.70 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:70.0) Gecko/20100101 Firefox/70.0',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:70.0) Gecko/20100101 Firefox/70.0',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36 OPR/68.0.3618.165',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Trident/7.0; rv:11.0) like Gecko',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           },
           {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36 Edg/83.0.478.37',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
           }
]

# %% [markdown]
# #### Step 3: Read Extractor Files
#
# The extractor (.yml) files contain *css id* information about the fields which we intend to extract from the scarped website. Here, the two extractor files are:
# ##### 1. product_list.yml
# From the scraped webpage, this extractor file extracts the main *css division* which contains all the individual (child) products. Once the main div is scraped, it extracts all the child divisions (products) contained in it.
# ##### 2. nextpg.yml
# Extracts the 'next' button from the website, to check if its disabled. If it is disabled, it means that we have reached the end of the product list for the current brand. We then move onto the next brand to continue our scraping.

# %%
e = Extractor.from_yaml_file('./Extractor/product_list.yml')
l = Extractor.from_yaml_file('./Extractor/nextpg.yml')

# %% [markdown]
# #### Step 4: Define scrape function
# **NOTE:** Set the variables MAX_TRIALS & ERROR_THRESHHOLD according to your preferences.
#
# A high MAX_TRIALS will slow down the scraping as it will scrape those pages without actually any data multiple times too, but it will reduce the chances of error.
# A low ERROR_THRESHHOLD will also slow down the scraping, as VPN will need to changed multiple times. However, it will reduce the chances missing data due to errors.
#
# The function scrape(url) downloads the webpage at the given url (here: product list pages) using requests module, and looks for products on the page. If it finds any product, it extracts the required fields and returns the data. If no product is found, it continues to randomly select a new header and retry scraping untill the limit MAX_TRIALS is reached, where it concludes that the page does not contain any data.
#
# These multiple trials are required, as amazon often blocks a user for repeqatedly making requests using the same user agent.

# %%
MAX_TRIALS = 15 # Set the max number of trials to perform here.
ERROR_COUNT = 1 # Used for keeping a count of errors, if the count exceeds threshhold, the user is asked to
                # change the vpn
    
ERROR_THRESHHOLD = 10 # Number of pages with missed information after which vpn change is required
def scrape(url):  
    global MAX_TRIALS
    global ERROR_COUNT
    global ERROR_THRESHHOLD
    '''
    This function downloads the webpage at the given url using requests module.
    
    Parameters:
    url (string): URL of webpage to scrape
    Returns: 
    string: If the URL contains products, returns the html of the webpage as text, else returns 'False'.
    '''
    
    # Download the page using requests
    print("Downloading %s"%url)
    trial = 0
    while(True):
        if ERROR_COUNT % ERROR_THRESHHOLD == 0:
            _ = input('Please Change VPN and press any key to continue')
            ERROR_COUNT += 1
        if trial == MAX_TRIALS:  
            print("Max trials exceeded yet no Data found on this page!")
            ERROR_COUNT += 1
            return 'False'
        trial = trial + 1
        print("Trial no:", trial)
        
        # Get the html data from the url
        while True:
            try:
                r = requests.get(url, headers=random.choice(headers), timeout = 15) 
                
                # We use product_list.yml extractor to extract the product details from the html data text
                data = e.extract(r.text) 
                # If the products div in the scraped html is not empty, return html text. 
                #If the products div in the scraped html is empty, retry with new user agent.
                if (data['products'] != None): 
                    return r.text
                else:
                    print("Retrying with new user agent!")
                    break
            except requests.exceptions.RequestException as err:
                print('Error Detected: ', err)
                print('Retrying after 30 seconds')
                sleep(30)
                continue
            except requests.exceptions.HTTPError as err:
                print('Error Detected: ', err)
                print('Retrying after 30 seconds')
                sleep(30)
                continue
            except requests.exceptions.ConnectionError as err:
                print('Error Detected: ', err)
                print('Retrying after 30 seconds')
                sleep(30)
                continue
            except requests.exceptions.Timeout as err:
                print('Error Detected: ', err)
                print('Retrying after 30 seconds')
                sleep(30)
                continue

# %% [markdown]
# #### Step 5: Initialise path of output file
#
# **NOTE:** Set the File Name accoring to what is being scraped here
#
# Eg: SCRAPED_PRODUCT_LIST_APPARIO or SCRAPED_PRODUCT_LIST_CLOUDTAIL

# %%
FileName = input('Enter a Filename for output file!\n')

outfile_path = str('./ScriptOutput/DATASET/' + str(FileName) + '.jsonl')
# Out:
# Enter a Filename for output file!
# ProductListAppario_NewWithHtmlPages

# %% [markdown]
# #### Step 6: Enter Seller Name
#
# Enter Seller Name which the brand list is associated with.
# Eg: Cloudtail India or Appario Retail Pvt Ltd

# %%
seller = input('Enter Seller Name!\n')
# Out:
# Enter Seller Name!
# Appario Retail Private Ltd

# %% [markdown]
# #### Step 7: Defining Functions to clean the data.

# %%
def CleanRating(s):
    '''
    Here, the input is rating in a string format, eg: "3.3 out of 5 stars".
    The function converts it to a float, eg: '3.3'
    '''
    if s is not None:
        try:
            return float(s.split(' ')[0])
        except ValueError:
            return None
        except AttributeError:
            return None
    else:
        return None

def CleanRatingCount(s):
    '''
    Here, the input is RatingCount in a string format, eg: "336 ratings".
    The function converts it to a float, eg: '336'
    '''
    if s is not None:
        return float(s.split(' ')[0].replace(',', ''))
    else:
        return float(0)
    
def CleanAmazonPrice(s):
    '''
    Here, the input is AmazonPrice in a string format, eg: "₹ 336.00".
    The function converts it to a float, eg: '336'
    '''
    if s is not None:
        print(s)
        s = s.replace('₹', '').replace(',', '').replace(r'\x', '').replace('a', '')
        return float(s.strip().split(' ')[0])
    else:
        return s

# %% [markdown]
# #### Step 8: Begin Main Scraping
#
# ##### NOTE: CHANGE THE URL BASED ON THE SELLER
#
# EG:
#
# Cloudtail URLs-> https://www.amazon.in/s?i=merchant-items&me=AT95IG9ONZD7S&rh=p_4%3AAmazon
#
# Appario URLS-> https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3Amazon
#
# Note that using both these urls, we are searching for 'Amazon' brand products, but first url searches for Amazon brand products on Cloudtail Storefront, and second one on Appario's.

# %%
with open(outfile_path,'a') as outfile:
    for b in brand_list:
        pg_number = 1
        
        while True:
                
            # To account for differnt urls based on page number
            if pg_number == 1:
                url = str("https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A"+str(b))
            else:
                url = str("https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A"+str(b)+"&dc&page="+str(pg_number))

            data_text = scrape(url)

            # Case 1: Scraped page does not contain any products
            if data_text == 'False': 
                pass

            # Case 2: Scraped page contains products
            else: 
                # Extract all product details in a dict 'data' using the extractor file
                data = e.extract(data_text) 

                # Save html text to file
                html_files_path = str('./ScriptOutput/HTML/'+ str(FileName) + '/' + str(b) +'/Page_'+str(pg_number)+'.html')
                os.makedirs(os.path.dirname(html_files_path), exist_ok=True) # Create file to save our html data
                with open(html_files_path, 'w') as file:
                    file.write(data_text)

                # data['products'] is a dict which contains details of all products present on the scraped page
                for product in data['products']: 
                    product['Rating'] = CleanRating(product['Rating'])
                    product['RatingCount'] = CleanRatingCount(product['RatingCount'])
                    product['AmazonPrice'] = CleanAmazonPrice(product['AmazonPrice'])
                    product['SearchUrl'] = url
                    product['Brand'] = b
                    product['Seller'] = seller
                    date = datetime.datetime.now()
                    product['Timestamp'] = date.strftime("%c")
                    product['ProductPageUrl'] = str('https://www.amazon.in' + str(product['ProductPageUrl']))
                    print("Saving Product: %s"%product['Title'])
                    print(product)
                    json.dump(product,outfile)
                    outfile.write("\n")
                          
            # If next page is not available, break and go to next brand                  
            if l.extract(data_text)['last'] == 'Next →':
                break
            elif data_text == 'False':
                break
            else:
                pg_number += 1 # Incrementing page numbe
# Out:
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A10.or
# Trial no: 1
# Retrying with new user agent!
# Trial no: 2
# Retrying with new user agent!
# Trial no: 3
# Retrying with new user agent!
# Trial no: 4
# Retrying with new user agent!
# Trial no: 5
# Retrying with new user agent!
# Trial no: 6
# Retrying with new user agent!
# Trial no: 7
# Retrying with new user agent!
# Trial no: 8
# Retrying with new user agent!
# Trial no: 9
# Retrying with new user agent!
# Trial no: 10
# Retrying with new user agent!
# Trial no: 11
# Retrying with new user agent!
# Trial no: 12
# Retrying with new user agent!
# Trial no: 13
# Retrying with new user agent!
# Trial no: 14
# Retrying with new user agent!
# Trial no: 15
# Retrying with new user agent!
# Max trials exceeded yet no Data found on this page!
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT
# Trial no: 1
# 129
# Saving Product: 100FIT Tempered Glass for Vivo Y19/U20 (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Vivo Y19/U20 (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Glass-Screen-Coverage/dp/B08CDY6DM1/ref=sr_1_1?dchild=1&m=A14CZOWI0VEHLG&qid=1597502806&refinements=p_4%3A100FIT&s=merchant-items&sr=1-1', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:46 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for Samsung Galaxy A8 Star (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Samsung Galaxy A8 Star (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/JV-FIT-6/dp/B08CDWCSC4/ref=sr_1_2?dchild=1&m=A14CZOWI0VEHLG&qid=1597502806&refinements=p_4%3A100FIT&s=merchant-items&sr=1-2', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:46 2020'}
# 96
# Saving Product: 100FIT Carbon Fiber Armor Drop Tested Shock Proof TPU Back Case Cover for Samsung Galaxy M21/M30S
# {'Title': '100FIT Carbon Fiber Armor Drop Tested Shock Proof TPU Back Case Cover for Samsung Galaxy M21/M30S', 'Label': None, 'Rating': 3.1, 'RatingCount': 4.0, 'AmazonPrice': 96.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Carbon-Tested-Samsung-Galaxy/dp/B082PLYPYR/ref=sr_1_3?dchild=1&m=A14CZOWI0VEHLG&qid=1597502806&refinements=p_4%3A100FIT&s=merchant-items&sr=1-3', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:46 2020'}
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2
# Trial no: 1
# Retrying with new user agent!
# Trial no: 2
# Retrying with new user agent!
# Trial no: 3
# Retrying with new user agent!
# Trial no: 4
# Retrying with new user agent!
# Trial no: 5
# Retrying with new user agent!
# Trial no: 6
# Retrying with new user agent!
# Trial no: 7
# Retrying with new user agent!
# Trial no: 8
# Retrying with new user agent!
# Trial no: 9
# Retrying with new user agent!
# Trial no: 10
# Retrying with new user agent!
# Trial no: 11
# Retrying with new user agent!
# Trial no: 12
# Retrying with new user agent!
# Trial no: 13
# 139
# Saving Product: 100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Samsung Galaxy M10 (2019)
# {'Title': '100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Samsung Galaxy M10 (2019)', 'Label': None, 'Rating': 4.3, 'RatingCount': 4.0, 'AmazonPrice': 139.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Hardness-Protection-Samsung/dp/B082PND1X4/ref=sr_1_17?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-17', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for Asus Zenfone Max Pro M1 (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Asus Zenfone Max Pro M1 (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Zenfone-Screen-Coverage/dp/B08CDXCQX7/ref=sr_1_18?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-18', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 139
# Saving Product: 100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Redmi Note 8 (2019)
# {'Title': '100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Redmi Note 8 (2019)', 'Label': None, 'Rating': 4.1, 'RatingCount': 52.0, 'AmazonPrice': 139.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Curved-Hardness-Protection/dp/B082PNN651/ref=sr_1_19?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-19', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 139
# Saving Product: 100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Samsung Galaxy A30/A50/A50S (2019)
# {'Title': '100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Samsung Galaxy A30/A50/A50S (2019)', 'Label': None, 'Rating': 3.7, 'RatingCount': 13.0, 'AmazonPrice': 139.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Hardness-Protection-Samsung/dp/B082PMQJ99/ref=sr_1_20?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-20', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 139
# Saving Product: 100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Realme 2 pro
# {'Title': '100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Realme 2 pro', 'Label': None, 'Rating': 3.6, 'RatingCount': 15.0, 'AmazonPrice': 139.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Curved-Hardness-Protection/dp/B082PN9XH3/ref=sr_1_21?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-21', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for OnePlus 5 (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for OnePlus 5 (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': 4.0, 'RatingCount': 1.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-OnePlus-Screen-Coverage/dp/B08CDXCQX1/ref=sr_1_22?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-22', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for Honor Play (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Honor Play (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': 1.0, 'RatingCount': 1.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Glass-Screen-Coverage/dp/B08CDXTSVF/ref=sr_1_23?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-23', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for Vivo Y19/U20 (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Vivo Y19/U20 (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Glass-Screen-Coverage/dp/B08CDY6DM1/ref=sr_1_24?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-24', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for Honor 9N (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Honor 9N (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Glass-Screen-Coverage/dp/B08CDXC1PY/ref=sr_1_25?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-25', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 139
# Saving Product: 100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Redmi Note 4
# {'Title': '100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Redmi Note 4', 'Label': None, 'Rating': 3.1, 'RatingCount': 20.0, 'AmazonPrice': 139.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Curved-Hardness-Protection/dp/B082PMPDYG/ref=sr_1_26?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-26', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for Vivo S1/Z1X (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Vivo S1/Z1X (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Glass-Screen-Coverage/dp/B08CDXZK4J/ref=sr_1_27?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-27', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for Honor View 20 (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Honor View 20 (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Glass-Screen-Coverage/dp/B08CDWYX6T/ref=sr_1_28?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-28', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 129
# Saving Product: 100FIT Tempered Glass for Samsung Galaxy A8 Star (11D)-Edge to Edge Full Screen Coverage
# {'Title': '100FIT Tempered Glass for Samsung Galaxy A8 Star (11D)-Edge to Edge Full Screen Coverage', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 129.0, 'ProductPageUrl': 'https://www.amazon.in/JV-FIT-6/dp/B08CDWCSC4/ref=sr_1_29?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-29', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 139
# Saving Product: 100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for (11D Tempered Glass, Redmi 7A (2019))
# {'Title': '100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for (11D Tempered Glass, Redmi 7A (2019))', 'Label': None, 'Rating': 4.5, 'RatingCount': 2.0, 'AmazonPrice': 139.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Curved-Hardness-Protection/dp/B082PLCDCW/ref=sr_1_30?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-30', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 139
# Saving Product: 100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Redmi 7/Redmi Y3
# {'Title': '100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Redmi 7/Redmi Y3', 'Label': None, 'Rating': 3.7, 'RatingCount': 5.0, 'AmazonPrice': 139.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Curved-Hardness-Protection/dp/B082PMLMXF/ref=sr_1_31?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-31', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# 139
# Saving Product: 100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Oppo F9/F9 pro
# {'Title': '100FIT 11D Tempered Glass with Curved Edges and 9H Hardness Full Glue Edge to Edge Screen Protection for Oppo F9/F9 pro', 'Label': None, 'Rating': 1.4, 'RatingCount': 3.0, 'AmazonPrice': 139.0, 'ProductPageUrl': 'https://www.amazon.in/100FIT-Tempered-Curved-Hardness-Protection/dp/B082PM2DJ6/ref=sr_1_32?dchild=1&m=A14CZOWI0VEHLG&qid=1597502815&refinements=p_4%3A100FIT&s=merchant-items&sr=1-32', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=2', 'Brand': '100FIT', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:16:55 2020'}
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A100FIT&dc&page=3
# Trial no: 1
# Retrying with new user agent!
# Trial no: 2
# Retrying with new user agent!
# Trial no: 3
# Retrying with new user agent!
# Trial no: 4
# Retrying with new user agent!
# Trial no: 5
# Retrying with new user agent!
# Trial no: 6
# Retrying with new user agent!
# Trial no: 7
# Retrying with new user agent!
# Trial no: 8
# Retrying with new user agent!
# Trial no: 9
# Retrying with new user agent!
# Trial no: 10
# Retrying with new user agent!
# Trial no: 11
# Retrying with new user agent!
# Trial no: 12
# Retrying with new user agent!
# Trial no: 13
# Retrying with new user agent!
# Trial no: 14
# Retrying with new user agent!
# Trial no: 15
# Retrying with new user agent!
# Max trials exceeded yet no Data found on this page!
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A1KLICK
# Trial no: 1
# 480
# Saving Product: 1KLICK G7 Optical Gaming Mouse (Black)
# {'Title': '1KLICK G7 Optical Gaming Mouse (Black)', 'Label': None, 'Rating': 3.6, 'RatingCount': 46.0, 'AmazonPrice': 480.0, 'ProductPageUrl': 'https://www.amazon.in/1KLICK-G7-Optical-Gaming-Mouse/dp/B07CKDP3XX/ref=sr_1_1?dchild=1&m=A14CZOWI0VEHLG&qid=1597502824&refinements=p_4%3A1KLICK&s=merchant-items&sr=1-1', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A1KLICK', 'Brand': '1KLICK', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:05 2020'}
# 579
# Saving Product: 1KLICK Wireless Mouse
# {'Title': '1KLICK Wireless Mouse', 'Label': None, 'Rating': 3.7, 'RatingCount': 4.0, 'AmazonPrice': 579.0, 'ProductPageUrl': 'https://www.amazon.in/1KLICK-1K-WM790-Wireless-Mouse/dp/B07PCT11ZY/ref=sr_1_2?dchild=1&m=A14CZOWI0VEHLG&qid=1597502824&refinements=p_4%3A1KLICK&s=merchant-items&sr=1-2', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A1KLICK', 'Brand': '1KLICK', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:05 2020'}
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A1KLICK&dc&page=2
# Trial no: 1
# Retrying with new user agent!
# Trial no: 2
# Retrying with new user agent!
# Trial no: 3
# Retrying with new user agent!
# Trial no: 4
# Retrying with new user agent!
# Trial no: 5
# Retrying with new user agent!
# Trial no: 6
# Retrying with new user agent!
# Trial no: 7
# Retrying with new user agent!
# Trial no: 8
# Retrying with new user agent!
# Trial no: 9
# Retrying with new user agent!
# Trial no: 10
# Retrying with new user agent!
# Trial no: 11
# Retrying with new user agent!
# Trial no: 12
# Retrying with new user agent!
# Trial no: 13
# Retrying with new user agent!
# Trial no: 14
# Retrying with new user agent!
# Trial no: 15
# Retrying with new user agent!
# Max trials exceeded yet no Data found on this page!
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A2010KHARIDO
# Trial no: 1
# Retrying with new user agent!
# Trial no: 2
# 479
# Saving Product: 2010kharido Smart Magnetic Trifold Case Cover + Slim Matte Back Case Cover For Apple iPad Air 1 1st Gen Red
# {'Title': '2010kharido Smart Magnetic Trifold Case Cover + Slim Matte Back Case Cover For Apple iPad Air 1 1st Gen Red', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 479.0, 'ProductPageUrl': 'https://www.amazon.in/2010kharido-Smart-Magnetic-Trifold-Cover/dp/B01MR6NGPT/ref=sr_1_1?dchild=1&m=A14CZOWI0VEHLG&qid=1597502835&refinements=p_4%3A2010KHARIDO&s=merchant-items&sr=1-1', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A2010KHARIDO', 'Brand': '2010KHARIDO', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:15 2020'}
# 201
# Saving Product: 2010kharido Silicone Compact Keyboard Skin Guard Cover Apple MacBook 12" with Retina Display Black
# {'Title': '2010kharido Silicone Compact Keyboard Skin Guard Cover Apple MacBook 12" with Retina Display Black', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 201.0, 'ProductPageUrl': 'https://www.amazon.in/2010kharido-Silicone-Compact-Keyboard-Macbook/dp/B01EJPD0B2/ref=sr_1_2?dchild=1&m=A14CZOWI0VEHLG&qid=1597502835&refinements=p_4%3A2010KHARIDO&s=merchant-items&sr=1-2', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A2010KHARIDO', 'Brand': '2010KHARIDO', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:15 2020'}
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A2010KHARIDO&dc&page=2
# Trial no: 1
# Retrying with new user agent!
# Trial no: 2
# Retrying with new user agent!
# Trial no: 3
# Retrying with new user agent!
# Trial no: 4
# Retrying with new user agent!
# Trial no: 5
# Retrying with new user agent!
# Trial no: 6
# Retrying with new user agent!
# Trial no: 7
# Retrying with new user agent!
# Trial no: 8
# Retrying with new user agent!
# Trial no: 9
# Retrying with new user agent!
# Trial no: 10
# Retrying with new user agent!
# Trial no: 11
# Retrying with new user agent!
# Trial no: 12
# Retrying with new user agent!
# Trial no: 13
# Retrying with new user agent!
# Trial no: 14
# Retrying with new user agent!
# Trial no: 15
# Retrying with new user agent!
# Max trials exceeded yet no Data found on this page!
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M
# Trial no: 1
# Retrying with new user agent!
# Trial no: 2
# 160
# Saving Product: 3M Scotch Packing Tape 48mm*50m White(Pack of 2)
# {'Title': '3M Scotch Packing Tape 48mm*50m White(Pack of 2)', 'Label': None, 'Rating': 4.3, 'RatingCount': 219.0, 'AmazonPrice': 160.0, 'ProductPageUrl': 'https://www.amazon.in/Scotch-Packing-Tape-48mm-White/dp/B01CSGVBZQ/ref=sr_1_1?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-1', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 140
# Saving Product: Post-it Sticky Notes (3" X 3") - Pack of 2 (2x100 Sheets, Canary Yellow)
# {'Title': 'Post-it Sticky Notes (3" X 3") - Pack of 2 (2x100 Sheets, Canary Yellow)', 'Label': None, 'Rating': 4.4, 'RatingCount': 200.0, 'AmazonPrice': 140.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Post-Yellow-Notes-Pack/dp/B01CSGVF1G/ref=sr_1_2?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-2', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 230
# Saving Product: Scotch Magic Tape - The Original Matte-Finish Invisible Tape by 3M, Pack of 2 (2 Rolls, Width 1.9cm Length 25.4m)
# {'Title': 'Scotch Magic Tape - The Original Matte-Finish Invisible Tape by 3M, Pack of 2 (2 Rolls, Width 1.9cm Length 25.4m)', 'Label': None, 'Rating': 4.4, 'RatingCount': 243.0, 'AmazonPrice': 230.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Scotch-Magic-Tape-Refill/dp/B01CSGVBTW/ref=sr_1_3?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-3', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 130
# Saving Product: 3M Post-It Flags - Pack of 2
# {'Title': '3M Post-It Flags - Pack of 2', 'Label': 'Best seller', 'Rating': 4.4, 'RatingCount': 212.0, 'AmazonPrice': 130.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Post-Flags-Pack-2/dp/B01CSGVDCW/ref=sr_1_4?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-4', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 150
# Saving Product: 3M Scotch White Glue Stick - Pack of 5
# {'Title': '3M Scotch White Glue Stick - Pack of 5', 'Label': None, 'Rating': 4.3, 'RatingCount': 122.0, 'AmazonPrice': 150.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Scotch-White-Glue-Stick/dp/B01CSGVBTC/ref=sr_1_5?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-5', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 150
# Saving Product: 3M Scotch Purple Glue Stick - Pack of 5
# {'Title': '3M Scotch Purple Glue Stick - Pack of 5', 'Label': None, 'Rating': 4.1, 'RatingCount': 20.0, 'AmazonPrice': 150.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Scotch-Purple-Glue-Stick/dp/B01CSGVDBS/ref=sr_1_6?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-6', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 150
# Saving Product: Post-it Yellow Notes (2" X 3") - Pack of 3 (3x100 Sheets, Canary Yellow)
# {'Title': 'Post-it Yellow Notes (2" X 3") - Pack of 3 (3x100 Sheets, Canary Yellow)', 'Label': None, 'Rating': 4.4, 'RatingCount': 67.0, 'AmazonPrice': 150.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Post-Yellow-Notes-Pack/dp/B01CSGVF16/ref=sr_1_7?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-7', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 180
# Saving Product: 3M Post-it Flags - Pack of 3
# {'Title': '3M Post-it Flags - Pack of 3', 'Label': None, 'Rating': 3.5, 'RatingCount': 45.0, 'AmazonPrice': 180.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Post-Flags-Pack-3/dp/B01CSH5MT6/ref=sr_1_8?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-8', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 160
# Saving Product: 3M Scotch Purple Glue Stick - Pack of 4
# {'Title': '3M Scotch Purple Glue Stick - Pack of 4', 'Label': None, 'Rating': 3.5, 'RatingCount': 28.0, 'AmazonPrice': 160.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Scotch-Purple-Glue-Stick/dp/B01CSGVDIG/ref=sr_1_9?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-9', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 140
# Saving Product: 3M Post-it Shaped Notes - Pack of 2
# {'Title': '3M Post-it Shaped Notes - Pack of 2', 'Label': None, 'Rating': 3.9, 'RatingCount': 8.0, 'AmazonPrice': 140.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Post-Shaped-Notes-Pack/dp/B01CSGVF02/ref=sr_1_10?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-10', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 260
# Saving Product: 3M Student Kit - Scotch Magic tape 8.8m, Post-it Color Notes 3in x 3in x 4clrx25sh, Scotch Glue stick 8g
# {'Title': '3M Student Kit - Scotch Magic tape 8.8m, Post-it Color Notes 3in x 3in x 4clrx25sh, Scotch Glue stick 8g', 'Label': None, 'Rating': 2.4, 'RatingCount': 2.0, 'AmazonPrice': 260.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Student-Kit-Post-4clrx25sh/dp/B07TQ9661C/ref=sr_1_11?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-11', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 360
# Saving Product: Scotch Magic Tape - The Original Matte-Finish Invisible Tape by 3M, Pack of 2 (2 Rolls, Width 1.9cm & 3M Post-It Flags - Pack of 2
# {'Title': 'Scotch Magic Tape - The Original Matte-Finish Invisible Tape by 3M, Pack of 2 (2 Rolls, Width 1.9cm & 3M Post-It Flags - Pack of 2', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 360.0, 'ProductPageUrl': 'https://www.amazon.in/Scotch-Magic-Tape-Matte-Finish-Post/dp/B08DF9K4C2/ref=sr_1_12?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-12', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 325
# Saving Product: 3M Post-It Flags - Pack of 2 & 3M Post-it Color Page Marker - Pack of 3
# {'Title': '3M Post-It Flags - Pack of 2 & 3M Post-it Color Page Marker - Pack of 3', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 325.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Post-Flags-Color-Marker/dp/B08DF8XJS6/ref=sr_1_13?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-13', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 340
# Saving Product: 3M Post-It Flags - Pack of 2 & Post-it 4 Color Page Markers -Pack of 3 (0.75" X 3", 4 x 200 Sheets, Colors May Vary)
# {'Title': '3M Post-It Flags - Pack of 2 & Post-it 4 Color Page Markers -Pack of 3 (0.75" X 3", 4 x 200 Sheets, Colors May Vary)', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 340.0, 'ProductPageUrl': 'https://www.amazon.in/3M-Post-Flags-Markers-Sheets/dp/B08DFBC4ZQ/ref=sr_1_14?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-14', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# 335
# Saving Product: Post-it Sticky Notes (3" X 3") - Pack of 2 (2x100 Sheets, Canary Yellow) & 3M Post-it Color Page Marker - Pack of 3
# {'Title': 'Post-it Sticky Notes (3" X 3") - Pack of 2 (2x100 Sheets, Canary Yellow) & 3M Post-it Color Page Marker - Pack of 3', 'Label': None, 'Rating': None, 'RatingCount': 0.0, 'AmazonPrice': 335.0, 'ProductPageUrl': 'https://www.amazon.in/Post-Sticky-Notes-Sheets-Canary/dp/B08DFB925G/ref=sr_1_15?dchild=1&m=A14CZOWI0VEHLG&qid=1597502844&refinements=p_4%3A3M&s=merchant-items&sr=1-15', 'SearchUrl': 'https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M', 'Brand': '3M', 'Seller': 'Appario Retail Private Ltd', 'Timestamp': 'Sat Aug 15 20:17:24 2020'}
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A3M&dc&page=2
# Trial no: 1
# Retrying with new user agent!
# Trial no: 2
# Retrying with new user agent!
# Trial no: 3
# Retrying with new user agent!
# Trial no: 4
# Retrying with new user agent!
# Trial no: 5
# Retrying with new user agent!
# Trial no: 6
# Retrying with new user agent!
# Trial no: 7
# Retrying with new user agent!
# Trial no: 8
# Retrying with new user agent!
# Trial no: 9
# Retrying with new user agent!
# Trial no: 10
# Retrying with new user agent!
# Trial no: 11
# Retrying with new user agent!
# Trial no: 12
# Retrying with new user agent!
# Trial no: 13
# Retrying with new user agent!
# Trial no: 14
# Retrying with new user agent!
# Trial no: 15
# Retrying with new user agent!
# Max trials exceeded yet no Data found on this page!
# Downloading https://www.amazon.in/s?i=merchant-items&me=A14CZOWI0VEHLG&rh=p_4%3A4+D+%28LABEL%29

# %% [markdown]
# #### Step 9: Read .jsonl File

# %%
# ProductListFile = open('./ScriptOutput/DATASET/test.jsonl', 'r')
ProductListFile = open(outfile_path)

ProductList = []
reader = jsonlines.Reader(ProductListFile)
for item in reader.iter():
    ProductList.append(item)
    
df = pd.DataFrame(ProductList)
print(df.count())
df.head()
# Out:
# Title                     7
# Brand                     7
# Rating                    7
# RatingCount               7
# AnsweredQuestionsCount    7
# MRP                       4
# AmazonPrice               7
# Savings                   4
# ShortDescription          7
# ProductDescription        0
# BestSellerRank            0
# DateFirstAvailable        0
# Breadcrumbs               0
# Seller                    7
# FullfilledBy              7
# Availability              7
# ProductPageUrl            7
# ASIN                      7
# DiscountPercentage        4
# Keywords                  0
# dtype: int64
#                                                Title          Brand  Rating  \
# 0  Fire TV Stick streaming media player with Alex...  Brand: Amazon     4.2
# 1  Echo Dot (3rd Gen) – New and improved smart sp...  Brand: Amazon     4.3
# 2  Echo Dot (3rd Gen) – New and improved smart sp...         Amazon     4.3
# 3  All-New Alexa Voice Remote with Power and Volu...  Brand: Amazon     4.1
# 4  Echo Dot (3rd Gen) – New and improved smart sp...         Amazon     4.3
#
#    RatingCount  AnsweredQuestionsCount     MRP  AmazonPrice  Savings  \
# 0      26423.0                  1000.0     NaN       3999.0      NaN
# 1      26950.0                  1000.0  4499.0       3499.0   1000.0
# 2      26950.0                  1000.0  4499.0       3499.0   1000.0
# 3       1286.0                   675.0     NaN       1999.0      NaN
# 4      26950.0                  1000.0  4499.0       3499.0   1000.0
#
#                                     ShortDescription ProductDescription  \
# 0  #1 best-selling streaming media player, with a...               None
# 1  Our most popular smart speaker with 360 degree...               None
# 2  Our most popular smart speaker with 360 degree...               None
# 3  Compatible with Fire TV Stick(2nd Generation),...               None
# 4  Our most popular smart speaker with 360 degree...               None
#
#   BestSellerRank DateFirstAvailable Breadcrumbs           Seller  \
# 0           None               None        None  Cloudtail India
# 1           None               None        None  Cloudtail India
# 2           None               None        None  Cloudtail India
# 3           None               None        None  Cloudtail India
# 4           None               None        None  Cloudtail India
#
#           FullfilledBy Availability  \
# 0  Fulfilled by Amazon    Available
# 1  Fulfilled by Amazon    Available
# 2  Fulfilled by Amazon    Available
# 3  Fulfilled by Amazon    Available
# 4  Fulfilled by Amazon    Available
#
#                                       ProductPageUrl        ASIN  \
# 0  https://www.amazon.in/Amazon-FireTVStick-Alexa...  B0791YHVMK
# 1  https://www.amazon.in/All-new-Echo-Dot-3rd-Gen...  B07PFFMP9P
# 2  https://www.amazon.in/All-new-Echo-Dot-3rd-Gen...  B07PKXJN7J
# 3  https://www.amazon.in/Amazon-FireTV-Stick-Alex...  B07B6NCTWB
# 4  https://www.amazon.in/C78MP8/dp/B07PGL2ZSL/ref...  B07PGL2ZSL
#
#    DiscountPercentage Keywords
# 0                 NaN     None
# 1                22.0     None
# 2                22.0     None
# 3                 NaN     None
# 4                22.0     None
